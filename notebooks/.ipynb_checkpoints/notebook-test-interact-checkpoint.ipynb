# %%
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/Gui/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# # Mean vs Median

# %%
from scipy.stats import exponnorm

def plot_mean_median(K):
    #data
    data = exponnorm.rvs(K, size=1000) #for histogram
    rv = exponnorm(K) #for the pdf
    x = np.linspace(exponnorm.ppf(0.01, K), exponnorm.ppf(0.99, K), 100) #x for the pdf
    #plot
    fig,ax = plt.subplots(figsize=(10, 4))
    ax.hist(data, bins=30, normed=True, color='0.65')
    ax.plot(x, rv.pdf(x), 'k-')
    ax.axvline(np.mean(data), color='#d62728', label='mean')
    ax.axvline(np.median(data), color='#1f77b4', label='median')
    ax.legend(loc='upper right')
    ax.set_xlim(-4, 65)
    ax.set_xlabel('Value', size=16)
    ax.set_ylabel('#', size=16)
    plt.show()

interact(plot_mean_median, K=(0.04, 10, 0.01))

# %%
from scipy.stats import weibull_min

def plot_mean_median2(K):
    #data
    data = weibull_min.rvs(K, size=1000) #for histogram
    rv = weibull_min(K) #for the pdf
    x = np.linspace(weibull_min.ppf(0.01, K), weibull_min.ppf(0.99, K), 100) #x for the pdf
    #plot
    fig,ax = plt.subplots(figsize=(10, 4))
    ax.hist(data, bins=30, normed=True, color='0.65')
    ax.plot(x, rv.pdf(x), 'k-')
    ax.axvline(np.mean(data), color='#d62728', label='mean')
    ax.axvline(np.median(data), color='#1f77b4', label='median')
    ax.legend(loc='upper right')
    ax.set_xlabel('Value', size=16)
    ax.set_ylabel('#', size=16)
    plt.show()

interact(plot_mean_median2, K=(0.5, 4, 0.1))
# Out:
# <function __main__.plot_mean_median2>
